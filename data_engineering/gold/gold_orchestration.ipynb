# %% [markdown]
# # Gold Layer - Orchestration
#
# This notebook runs Gold build notebooks in sequence.
#
# ## Tools and Operations
# - **`dbutils.notebook.run`** execution flow
# - Basic run logging for each step
#
# ## Workflow
# 1. Build `gold_dim_customers`
# 2. Build `gold_dim_products`
# 3. Build `gold_fact_sales`

# %%
notebooks = [
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
